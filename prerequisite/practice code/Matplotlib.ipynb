# %%
import matplotlib.pyplot as plt
# Out:
# c:\users\satya\appdata\local\programs\python\python39\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\users\satya\appdata\local\programs\python\python39\lib\site-packages\numpy\.libs\libopenblas.GK7GX5KEQ4F6UYO3P26ULGBQYHGQO7J4.gfortran-win_amd64.dll
# c:\users\satya\appdata\local\programs\python\python39\lib\site-packages\numpy\.libs\libopenblas.JPIJNSWNNAN3CE6LLI5FWSPHUT2VXMTH.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %% [markdown]
# # plottting graphs

# %%
x=range(100)

# %%
y=[v**2 for v in x]

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# ### scratch to numpy example

# %%
import math
import matplotlib.pyplot as plt
T=range(100)
X=[(2*math.pi*t)/len(T) for t in T]
Y=[math.sin(value) for value in X]
plt.plot(X,Y)
plt.show()

# %%
import numpy as np
X=np.linspace(0,2*np.pi,100)
Y=np.sin(X)
plt.plot(X,Y)
plt.show()

# %%
X=np.linspace(-3,2,200)
Y=X**2-2*X+1
plt.plot(X,Y)
plt.show()

# %%
X=np.linspace(0,2*np.pi,100)
Ya=np.sin(X)
Yb=np.cos(X)
plt.plot(X,Ya)
plt.plot(X,Yb)
plt.show()

# %%
def plot_slope(X, Y):
    Xs = X[1:] - X[:-1]
    Ys = Y[1:] - Y[:-1]
    plt.plot(X[1:], Ys / Xs)
X = np.linspace(-3, 3, 100)
Y = np.exp(-X ** 2)
plt.plot(X, Y)
plot_slope(X, Y)

# %%
X, Y=[],[]
for line in open('data1.txt','r'):
    values = [float(s) for s in line.split()]
    X.append(values[0])
    Y.append(values[1])
plt.plot(X,Y)

# %%
with open('data1.txt', 'r') as f:
    X, Y = zip(*[[float(s) for s in line.split()] for line in f])
plt.plot(X, Y)
plt.show()

# %%
X=[1,2,3,4,5]
Y=[1,4,9,16,25]
Z=[1,8,27,64,125]
plt.plot(X,Y)
plt.plot(X,Z)

# %%
data = np.loadtxt('data2.txt')
for column in data.T:
    plt.plot(data[:,0], column)
plt.show()

# %% [markdown]
# # plotting points

# %%
data=np.random.rand(1024,2)
data
# Out:
# array([[0.12746193, 0.2887164 ],
#        [0.61234682, 0.0091507 ],
#        [0.58232628, 0.35224363],
#        ...,
#        [0.33782673, 0.79935555],
#        [0.59428486, 0.5086729 ],
#        [0.37187657, 0.48429526]])

# %%
plt.scatter(data[:,0],data[:,1])

# %%
X=range(1,21)
Y=[x**2 for x in X]
plt.scatter(X,Y)

# %% [markdown]
# ## plotting bar charts

# %%
X=range(1,21)
Y=[x**2 for x in X]
plt.bar(X,Y)
plt.show()

# %%
plt.barh(X,Y)
plt.show()

# %%
plt.bar(X,Y,width=.1)
plt.show()

# %%
W=np.arange(1,6)
X=[w**2 for w in W]
Y=[(w**3) for w in W]
plt.bar(W,W,color='b',width=0.25)
plt.bar(W+.25,X,color='g',width=0.25)
plt.bar(W+.5,Y,color='r',width=0.25)
plt.show()

# %%
W=np.arange(1,6)
X=[w**2 for w in W]
Y=[(w**3) for w in W]
plt.bar(W,X,color='b')
plt.bar(W,Y,color='r',bottom=X)
# Out:
# <BarContainer object of 5 artists>

# %%
A = np.array([5., 30., 10., 22.])
B = np.array([5., 25., 20., 20.])
C = np.array([2., 3., 2., 2.])
X = np.arange(4)
plt.bar(X, A, color = 'b')
plt.bar(X, B, color = 'g', bottom = A)
plt.bar(X, C, color = 'r', bottom = A + B)
plt.show()

# %%
X=np.arange(1,6)
Y=np.array([x**2 for x in X])
Z=np.array([(x**3) for x in X])
plt.barh(X,-Y,color='blue')
plt.barh(X,Z,color='orange')
# Out:
# <BarContainer object of 5 artists>

# %%
X=np.arange(1,6)
Y=np.array([x**2 for x in X])
Z=np.array([(x**3) for x in X])
plt.bar(X,-Y,color='blue')
plt.bar(X,Z,color='orange')
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# ## plotting pie chart

# %%
X=[10,20,30,40]
plt.pie(X)
plt.show()

# %% [markdown]
# ## plotting histogram

# %%
X = np.random.randn(1000)
plt.hist(X, bins = 20)
plt.show()

# %% [markdown]
# ## Plotting boxplots

# %%
data = np.random.randn(100)
plt.boxplot(data)
plt.show()

# %%
data = np.random.randn(100, 5)
plt.boxplot(data)
plt.show()

# %%
plt.boxplot([data[:,0],data[:,1]])
plt.show()

# %%
import matplotlib.tri as tri
data = np.random.rand(100, 2)
triangles = tri.Triangulation(data[:,0], data[:,1])
plt.triplot(triangles)
plt.show()

# %%
X=np.arange(1,6)
Y=np.array([x**99 for x in X])
triangles = tri.Triangulation(X,Y)
plt.triplot(triangles)
plt.show()

# %% [markdown]
# # Coloring

# %%
import numpy as np
import matplotlib.pyplot as plt
def pdf(X, mu, sigma):
    a = 1. / (sigma * np.sqrt(2. * np.pi))
    b = -1. / (2. * sigma ** 2)
    return a * np.exp(b * (X - mu) ** 2)
X = np.linspace(-6, 6, 1000)
for i in range(5):
    samples = np.random.standard_normal(50)
    mu, sigma = np.mean(samples), np.std(samples)
    plt.plot(X, pdf(X, mu, sigma), color = '.75')
plt.plot(X, pdf(X, 0., 1.), color = 'k')
plt.show()

# %%
A = np.random.standard_normal((100, 2))
A += np.array((-1, -1)) # Center the distrib. at <-1, -1>
B = np.random.standard_normal((100, 2))
B += np.array((1, 1)) # Center the distrib. at <1, 1>
plt.scatter(A[:,0], A[:,1], color = '.25')
plt.scatter(B[:,0], B[:,1], color = '.75')
plt.show()

# %%
label_set = (
 b'Iris-setosa',
 b'Iris-versicolor',
 b'Iris-virginica',
)
def read_label(label):
    return label_set.index(label)
data = np.loadtxt('iris.data.txt',delimiter = ',',converters = { 4 : read_label })
color_set = ('.00', '.50', '.75')
color_list = [color_set[int(label)] for label in data[:,4]]
plt.scatter(data[:,0], data[:,1], color = color_list)
plt.show()

# %%
a=[1,2,3,4,5,6,7]
b=[2,3,4,5,6,7,8]
plt.scatter(a,b,c=['b','g','r','c','m','y','w'],edgecolor='k')

# %%
values = np.random.random_integers(99, size = 50)
values=sorted(values)
color_set = ('.00', '.25', '.50', '.75')
color_list = [color_set[(len(color_set) * val) // 100] for val in 
 values]
plt.bar(np.arange(len(values)), values, color = color_list)
plt.show()
# Out:
# <ipython-input-36-1ed64347a9eb>:1: DeprecationWarning: This function is deprecated. Please call randint(1, 99 + 1) instead
#   values = np.random.random_integers(99, size = 50)

# %%
values =[30,45,45,45,30,45,45,45]
color_set = ('c', 'm', 'y')
plt.pie(values, colors = color_set)
plt.show()

# %%
values = np.random.randn(100)
b = plt.boxplot(values)
cls=['b','g','r','c','m','y','w']
i=0
for name, line_list in b.items():
    for line in line_list:
        line.set_color(cls[i])
        i+=1
plt.show()

# %%
for name, line_list in b.items():
    print(name,line_list)
# Out:
# whiskers [<matplotlib.lines.Line2D object at 0x000001C9306780A0>, <matplotlib.lines.Line2D object at 0x000001C930678340>]
# caps [<matplotlib.lines.Line2D object at 0x000001C930678A90>, <matplotlib.lines.Line2D object at 0x000001C930657220>]
# boxes [<matplotlib.lines.Line2D object at 0x000001C9306788B0>]
# medians [<matplotlib.lines.Line2D object at 0x000001C930657550>]
# fliers [<matplotlib.lines.Line2D object at 0x000001C930657730>]
# means []

# %%
for name, line_list in b.items():
    for line in line_list:
        print(line)
# Out:
# Line2D(_line1)
# Line2D(_line2)
# Line2D(_line3)
# Line2D(_line4)
# Line2D(_line0)
# Line2D(_line5)
# Line2D(_line6)

# %%
import matplotlib.cm as cm
N = 256
angle = np.linspace(0, 8 * 2 * np.pi, N)
radius = np.linspace(.5, 1., N)
X = radius * np.cos(angle)
Y = radius * np.sin(angle)
plt.scatter(X, Y, c = angle, cmap = cm.hsv)
plt.show()

# %%
import matplotlib.cm as cm
import matplotlib.colors as col
import matplotlib.pyplot as plt
values = np.random.random_integers(99, size = 50)
cmap = cm.ScalarMappable(col.Normalize(0, 99), cm.binary)
plt.bar(np.arange(len(values)), values, color = cmap.to_rgba(values))
plt.show()
# Out:
# <ipython-input-42-2f951d0cd2e8>:4: DeprecationWarning: This function is deprecated. Please call randint(1, 99 + 1) instead
#   values = np.random.random_integers(99, size = 50)

# %%
import numpy as np
import matplotlib.pyplot as plt
def pdf(X, mu, sigma):
    a = 1. / (sigma * np.sqrt(2. * np.pi))
    b = -1. / (2. * sigma ** 2)
    return a * np.exp(b * (X - mu) ** 2)
X = np.linspace(-6, 6, 1024)
plt.plot(X, pdf(X, 0., 1.), color = 'k', linestyle = 'solid')
plt.plot(X, pdf(X, 0., .5), color = 'k', linestyle = 'dashed')
plt.plot(X, pdf(X, 0., .25), color = 'k', linestyle = 'dashdot')
plt.plot(X, pdf(X, 0., 2), color = 'k', linestyle = 'dotted')
plt.show()

# %%
N = 8
A = np.random.random(N)
B = np.random.random(N)
X = np.arange(N)
plt.bar(X, A, color = '.75')
plt.bar(X, A + B, bottom = A, color = 'w', linestyle = 'dashdot')
plt.show()

# %%
def pdf(X, mu, sigma):
    a = 1. / (sigma * np.sqrt(2. * np.pi))
    b = -1. / (2. * sigma ** 2)
    return a * np.exp(b * (X - mu) ** 2)
X = np.linspace(-6, 6, 1024)
for i in range(64):
    samples = np.random.standard_normal(50)
    mu, sigma = np.mean(samples), np.std(samples)
    plt.plot(X, pdf(X, mu, sigma), color = '.75', linewidth = .5)
plt.plot(X, pdf(X, 0., 1.), color = 'k', linewidth = 3.)
plt.show()

# %%
N = 8
A = np.random.random(N)
B = np.random.random(N)
X = np.arange(N)
plt.bar(X, A, color = '.75',hatch='-',linestyle="dashed")
plt.bar(X, A + B, bottom = A, color = 'w',hatch="O",linestyle="dashed")
plt.show()
#/\|-Oo*.x+

# %%
A = np.random.standard_normal((100, 2))
print(A[:1,:2])
A += np.array((-1, -1))
A[:1,:2]
# Out:
# [[ 0.37157379 -1.05793349]]
# array([[-0.62842621, -2.05793349]])

# %%
A = np.random.standard_normal((100, 2))
A += np.array((-1, -1))
B = np.random.standard_normal((100, 2))
B += np.array((1, 1))
plt.scatter(A[:,0], A[:,1], color = 'k', marker = 'x')
plt.scatter(B[:,0], B[:,1], color = 'k', marker = '^')
plt.show()

# %%
label_list = (
 b'Iris-setosa',
 b'Iris-versicolor',
 b'Iris-virginica',
)
def read_label(label):
    return label_list.index(label)
data = np.loadtxt('iris.data.txt',
 delimiter = ',',
 converters = { 4 : read_label })
marker_set = ('^', 'x', '.')
for i, marker in enumerate(marker_set):
    data_subset = np.asarray([x for x in data if x[4] == i])
    plt.scatter(data_subset[:,0], data_subset[:,1],color = 'k', marker = marker)
plt.show()

# %%
X = np.linspace(-6, 6, 1024)
Y1 = np.sinc(X)
Y2 = np.sinc(X) + 1
plt.plot(X, Y1, marker = 'o', color = '.75')
plt.plot(X, Y2, marker = 'o', color = 'k', markevery = 32)
plt.show()

# %%
A = np.random.standard_normal((100, 2))
A += np.array((-1, -1))
B = np.random.standard_normal((100, 2))
B += np.array((1, 1))
plt.scatter(B[:,0], B[:,1], c = 'k', s = 10)
plt.scatter(A[:,0], A[:,1], c = 'r', s = 30)
plt.show()

# %%
M = np.random.standard_normal((1000, 2))
R = np.sum(M ** 2, axis = 1)
plt.scatter(M[:, 0], M[:, 1], c = 'r', marker = 's', s = 32. * R)
plt.show()

# %%
import numpy as np
import matplotlib.path as mpath
from matplotlib import pyplot as plt
shape_description = [
 ( 1., 2., mpath.Path.MOVETO),
 ( 1., 1., mpath.Path.LINETO),
 ( 2., 1., mpath.Path.LINETO),
 ( 2., -1., mpath.Path.LINETO),
 ( 1., -1., mpath.Path.LINETO),
 ( 1., -2., mpath.Path.LINETO),
 (-1., -2., mpath.Path.LINETO),
 (-1., -1., mpath.Path.LINETO),
 (-2., -1., mpath.Path.LINETO),
 (-2., 1., mpath.Path.LINETO),
 (-1., 1., mpath.Path.LINETO),
 (-1., 2., mpath.Path.LINETO),
 ( 0., 0., mpath.Path.CLOSEPOLY),
]
u, v, codes = zip(*shape_description)
my_marker = mpath.Path(np.asarray((u, v)).T, codes)
data = np.random.rand(8, 8)
plt.scatter(data[:,0], data[:, 1], c = '.75', marker = my_marker, s = 64)
plt.show()

# %%
X = np.linspace(-6, 6, 1024)
Y = np.sinc(X)
plt.plot(X, Y,
 linewidth = 3.,
 color = 'k',
 markersize = 9,
 markeredgewidth = 1.5,
 markerfacecolor = '.75',
 markeredgecolor = 'k',
 marker = 'o',
 markevery = 32)
plt.show()

# %%
"""import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
mpl.rc('lines', linewidth = 2.)
mpl.rc('axes', facecolor = 'k', edgecolor = 'w')
mpl.rc('xtick', color = 'w')
mpl.rc('ytick', color = 'w')
mpl.rc('text', color = 'w')
mpl.rc('figure', facecolor = 'w', edgecolor ='w')
mpl.rc('axes', prop_cycle = ('w', '.5', '.75'))
X = np.linspace(0, 7, 1024)
plt.plot(X, np.sin(X))
plt.plot(X, np.cos(X))
plt.show()"""
# Out:
# "import numpy as np\nimport matplotlib as mpl\nfrom matplotlib import pyplot as plt\nmpl.rc('lines', linewidth = 2.)\nmpl.rc('axes', facecolor = 'k', edgecolor = 'w')\nmpl.rc('xtick', color = 'w')\nmpl.rc('ytick', color = 'w')\nmpl.rc('text', color = 'w')\nmpl.rc('figure', facecolor = 'w', edgecolor ='w')\nmpl.rc('axes', prop_cycle = ('w', '.5', '.75'))\nX = np.linspace(0, 7, 1024)\nplt.plot(X, np.sin(X))\nplt.plot(X, np.cos(X))\nplt.show()"

# %% [markdown]
# # working with annotations

# %%
X = np.linspace(-4, 4, 1024)
Y = .25 * (X + 4.) * (X + 1.) * (X - 2.)
plt.title('A polynomial')
plt.plot(X, Y, c = 'k')
plt.show()

# %%
X = np.linspace(-4, 4, 1024)
Y = .25 * (X + 4.) * (X + 1.) * (X - 2.)
plt.title('$f(x)=\\frac{1}{4}(x+4)(x+1)(x-2)$')
plt.plot(X, Y, c = 'k')
plt.show()

# %%
X = np.linspace(-4, 4, 1024)
Y = .25 * (X + 4.) * (X + 1.) * (X - 2.)
plt.title('$f(x)=\\frac{1}{4}(x+4)(x+1)(x-2)$')
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.plot(X, Y, c = 'k')
plt.show()

# %%
X = [1,2,3,4,5,6,7,8,9]
Y = [1,2,3,4,5,6,7,8,9]
plt.text(3, 2, 'text')
plt.plot(X, Y, c = 'k')
plt.show()

# %%
X = [1,2,3,4,5,6,7,8,9]
Y = [1,2,3,4,5,6,7,8,9]
plt.text(2,3,'text',ha='right')
plt.plot(X, Y, c = 'k')
plt.show()

# %%
X = [1,2,3,4,5,6,7,8,9]
Y = [1,2,3,4,5,6,7,8,9]
box = {
 'facecolor' : '.75',
 'edgecolor' : 'r',
 'boxstyle' : 'round'
}
plt.text(2,3,'text',va='center',bbox=box)
plt.plot(X, Y, c = 'k')
plt.show()

# %%
X = [1,2,3,4,5,6,7,8,9]
Y = [1,2,3,4,5,6,7,8,9]
plt.annotate('annotation',ha = 'center', va = 'bottom',xytext = (2,5),xy = (2,2),
arrowprops = {'facecolor' : 'black', 'shrink' : 0.05 })
plt.plot(X, Y)
plt.show()

# %%
X = [1,2,3,4,5,6,7,8,9]
Y = [1,2,3,4,5,6,7,8,9]
plt.annotate('annotation',ha = 'center', va = 'bottom',xytext = (2,5),xy = (2,2),
arrowprops = {'arrowstyle':"<-", 'facecolor' : 'black', })
plt.plot(X, Y)
plt.show()

# %%
X = np.linspace(0, 6, 1024)
Y1 = np.sin(X)
Y2 = np.cos(X)
plt.xlabel('X')
plt.ylabel('Y')
plt.plot(X, Y1, c = 'k', lw = 3., label = 'sin(X)')
plt.plot(X, Y2, c = '.5', lw = 3., ls = '--', label = 'cos(X)')
plt.legend(title="how",fancybox=True,loc="best")
plt.show()

# %%
X = [1,2,3,4,5,6,7,8,9]
Y = [1,2,3,4,5,6,7,8,9]

plt.grid(True, lw = 2, ls = '--', c = 'r')
plt.plot(X, Y, c = 'k')
plt.show()

# %%
import matplotlib.pyplot as plt
N = 16
for i in range(N):
    plt.gca().add_line(plt.Line2D((0, i), (N - i, 0), ))
plt.grid(True)
plt.axis('scaled')
plt.show()
